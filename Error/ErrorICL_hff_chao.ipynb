# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
from astropy.visualization import simple_norm
import pyregion
plt.figure(figsize =(5*4,2*4))

ax1=plt.subplot(251)
icl=fits.open('../../../../f160w/error_icl_bcg/image/icl105.fits')[0].data
hdr=fits.open('../../../../f160w/error_icl_bcg/image/icl105.fits')[0].header
exptime=hdr['exptime']
norm=simple_norm(icl,stretch='asinh', min_cut=-0.007, max_cut=0.1)
ax1.imshow(icl/exptime,cmap='gray_r',norm=norm,origin='lower',aspect='auto')
ax1.text(200,2600,'$r_{out}$=105 pixels',color='b',fontsize=20,bbox=dict(facecolor='w', alpha=0.9, edgecolor='black'))
ax1.get_xaxis().set_visible(False)
ax1.get_yaxis().set_visible(False)

ax2=plt.subplot(252)
icl=fits.open('../../../../f160w/error_icl_bcg/image/icl107.fits')[0].data
norm=simple_norm(icl,stretch='asinh',min_cut=-0.007, max_cut=0.1)
ax2.imshow(icl/exptime,cmap='gray_r',norm=norm,origin='lower',aspect='auto')
ax2.text(200,2600,'$r_{out}$=107 pixels',color='b',fontsize=20,bbox=dict(facecolor='w', alpha=0.9, edgecolor='black'))
ax2.get_xaxis().set_visible(False)
ax2.get_yaxis().set_visible(False)

ax3=plt.subplot(253)
icl=fits.open('../../../../f160w/error_icl_bcg/image/icl109.fits')[0].data
norm=simple_norm(icl,stretch='asinh',min_cut=-0.007, max_cut=0.1)
ax3.imshow(icl/exptime,cmap='gray_r',norm=norm,origin='lower',aspect='auto')
ax3.text(200,2600,'$r_{out}$=109 pixels',color='b',fontsize=20,bbox=dict(facecolor='w', alpha=0.9, edgecolor='black'))
ax3.get_xaxis().set_visible(False)
ax3.get_yaxis().set_visible(False)

ax4=plt.subplot(254)
icl=fits.open('../../../../f160w/error_icl_bcg/image/icl111.fits')[0].data
norm=simple_norm(icl,stretch='asinh',min_cut=-0.007, max_cut=0.1)
ax4.imshow(icl/exptime,cmap='gray_r',norm=norm,origin='lower',aspect='auto')
ax4.text(200,2600,'$r_{out}$=111 pixels',color='b',fontsize=20,bbox=dict(facecolor='w', alpha=0.9, edgecolor='black'))
ax4.get_xaxis().set_visible(False)
ax4.get_yaxis().set_visible(False)

ax5=plt.subplot(255)
icl=fits.open('../../../../f160w/error_icl_bcg/image/icl113.fits')[0].data
norm=simple_norm(icl,stretch='asinh',min_cut=-0.007, max_cut=0.1)
ax5.imshow(icl/exptime,cmap='gray_r',norm=norm,origin='lower',aspect='auto')
ax5.text(200,2600,'$r_{out}$=113 pixels',color='b',fontsize=20,bbox=dict(facecolor='w', alpha=0.9, edgecolor='black'))
ax5.get_xaxis().set_visible(False)
ax5.get_yaxis().set_visible(False)

ax6=plt.subplot(256)
icl=fits.open('../../../../f160w/error_icl_bcg/image/icl115.fits')[0].data
norm=simple_norm(icl,stretch='asinh',min_cut=-0.007, max_cut=0.1)
ax6.imshow(icl/exptime,cmap='gray_r',norm=norm,origin='lower',aspect='auto')
ax6.text(200,2600,'$r_{out}$=115 pixels',color='b',fontsize=20,bbox=dict(facecolor='w', alpha=0.9, edgecolor='black'))
ax6.get_xaxis().set_visible(False)
ax6.get_yaxis().set_visible(False)

ax7=plt.subplot(257)
icl=fits.open('../../../../f160w/error_icl_bcg/image/icl117.fits')[0].data
norm=simple_norm(icl,stretch='asinh',min_cut=-0.007, max_cut=0.1)
ax7.imshow(icl/exptime,cmap='gray_r',norm=norm,origin='lower',aspect='auto')
ax7.text(200,2600,'$r_{out}$=117 pixels',color='b',fontsize=20,bbox=dict(facecolor='w', alpha=0.9, edgecolor='black'))
ax7.get_xaxis().set_visible(False)
ax7.get_yaxis().set_visible(False)

ax8=plt.subplot(258)
icl=fits.open('../../../../f160w/error_icl_bcg/image/icl119.fits')[0].data
norm=simple_norm(icl,stretch='asinh',min_cut=-0.007, max_cut=0.1)
ax8.imshow(icl/exptime,cmap='gray_r',norm=norm,origin='lower',aspect='auto')
ax8.text(200,2600,'$r_{out}$=119 pixels',color='b',fontsize=20,bbox=dict(facecolor='w', alpha=0.9, edgecolor='black'))
ax8.get_xaxis().set_visible(False)
ax8.get_yaxis().set_visible(False)

ax9=plt.subplot(259)
icl=fits.open('../../../../f160w/error_icl_bcg/image/icl121.fits')[0].data
norm=simple_norm(icl,stretch='asinh',min_cut=-0.007, max_cut=0.1)
ax9.imshow(icl/exptime,cmap='gray_r',norm=norm,origin='lower',aspect='auto')
ax9.text(200,2600,'$r_{out}$=121 pixels',color='b',fontsize=20,bbox=dict(facecolor='w', alpha=0.9, edgecolor='black'))
ax9.get_xaxis().set_visible(False)
ax9.get_yaxis().set_visible(False)

ax10=plt.subplot(2,5,10)
icl=fits.open('../../../../f160w/error_icl_bcg/image/icl123.fits')[0].data
norm=simple_norm(icl,stretch='asinh',min_cut=-0.007, max_cut=0.1)
ax10.imshow(icl/exptime,cmap='gray_r',norm=norm,origin='lower',aspect='auto')
ax10.text(200,2600,'$r_{out}$=123 pixels',color='b',fontsize=20,bbox=dict(facecolor='w', alpha=0.9, edgecolor='black'))
ax10.get_xaxis().set_visible(False)
ax10.get_yaxis().set_visible(False)

plt.tight_layout()
plt.subplots_adjust(wspace=0.0,hspace=0.0)
plt.savefig('multi_icl.jpg',dpi=120)
